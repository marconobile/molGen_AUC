# %% [markdown]
# ## Build a framework to build an "auc" to define the quality of a molecule generative model
# - step1: out of all the files in the game get their VALID version
# - merge sequentially smiles files and get number of mol via removing dupicates delta

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from source.rdkit_utils import get_valid_non_duplicates, save_smiles
from source.io_utils import delete_file, get_dir_filename_ext

# %%
out_path = Path("/home/nobilm@usi.ch/auc_generation/data/merges")

# %%
def preprocess_csv(path):
    dir, filename, ext = get_dir_filename_ext(path)
    lines = []
    with open(path) as f:
        for line in f:
            start = line.find(',') +1 
            line = line[start:]
            end = line.find(',')
            lines.append(line[:end])

    save_smiles(lines, dir, filename, '.smiles')

preprocess_csv("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_10k.csv")
preprocess_csv("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_60k.csv")
preprocess_csv("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_110k.csv")
preprocess_csv("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_160k.csv")
preprocess_csv("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_210k.csv")

# %%
def merge_files(file1, file2, output_file):
    with open(file1, 'r') as f1:
        content1 = f1.read()
    with open(file2, 'r') as f2:
        content2 = f2.read()
    
    with open(output_file, 'w+') as output:
        output.write(content1)
        output.write(content2)
    return output_file

def count_rows(file_path):
    with open(file_path, 'r') as file:
        row_count = sum(1 for line in file)
    return row_count

# %%
# To be taken as input from argparse
filelist = {    
    'file_1': Path("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_40k.smiles"),
    'file_2': Path("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_115k.smiles"),
    'file_3': Path("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_145k.smiles"),
    'file_4': Path("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_190k.smiles"),
    'file_5': Path("/home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_290k.smiles"),
}

# to be taken as input:
# - train file
# - ref file
# - folder of gen smiles

# for each one compute valid_unique
# compute intersection train/ref

# %%
# todo insert here compute intersection train/ref

# %%
# %%capture
for k, v in filelist.items():    
    filelist[k] = get_valid_non_duplicates(v)

# OUT: filelist = { k in [ref, train, file_0, file_1], val_non_dup_filepath.smiles}
# Out:
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# Removed  - a duplicate of  (#5)
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# Removed  - a duplicate of  (#7)
# Removed  - a duplicate of  (#8)
# Removed  - a duplicate of  (#9)
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# Removed  - a duplicate of  (#12)
# Removed  - a duplicate of  (#13)
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# Removed  - a duplicate of  (#16)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# Removed  - a duplicate of  (#35)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#36)
# Removed  - a duplicate of  (#37)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# Removed  - a duplicate of  (#43)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6);
# Removed  - a duplicate of  (#44)
# Removed  - a duplicate of  (#45)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# Removed  - a duplicate of  (#49)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# Removed  - a duplicate of  (#54)
# Removed  - a duplicate of  (#55)
# Removed  - a duplicate of  (#56)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2)
# Removed  - a duplicate of  (#57)
# Removed  - a duplicate of  (#58)
# Removed  - a duplicate of  (#59)
# Removed  - a duplicate of  (#60)
# Removed  - a duplicate of  (#61)
# Removed  - a duplicate of  (#62)
# Removed  - a duplicate of  (#63)
# Removed  - a duplicate of  (#64)
# Removed  - a duplicate of  (#65)
# Removed  - a duplicate of  (#66)
# Removed  - a duplicate of  (#67)
# Removed  - a duplicate of  (#68)
# Removed  - a duplicate of  (#69)
# Removed  - a duplicate of  (#70)
# Removed  - a duplicate of  (#71)
# Removed  - a duplicate of  (#72)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#73)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#74)
# Removed  - a duplicate of  (#75)
# Removed  - a duplicate of  (#76)
# Removed  - a duplicate of  (#77)
# Removed  - a duplicate of  (#78)
# Removed  - a duplicate of  (#79)
# Removed  - a duplicate of  (#80)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#81)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#82)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#83)
# Removed  - a duplicate of  (#84)
# Removed  - a duplicate of  (#85)
# Removed  - a duplicate of  (#86)
# Removed  - a duplicate of  (#87)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#88)
# Removed  - a duplicate of  (#89)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#90)
# Removed  - a duplicate of  (#91)
# Removed  - a duplicate of  (#92)
# Removed  - a duplicate of  (#93)
# Removed  - a duplicate of  (#94)
# Removed  - a duplicate of  (#95)
# Removed  - a duplicate of  (#96)
# Removed  - a duplicate of  (#97)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#98)
# Removed  - a duplicate of  (#99)
# Removed  - a duplicate of  (#100)
# Removed  - a duplicate of  (#101)
# Removed  - a duplicate of  (#102)
# Removed  - a duplicate of  (#103)
# Removed  - a duplicate of  (#104)
# Removed  - a duplicate of  (#105)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#106)
# Removed  - a duplicate of  (#107)
# Removed  - a duplicate of  (#108)
# Removed  - a duplicate of  (#109)
# Removed  - a duplicate of  (#110)
# Removed  - a duplicate of  (#111)
# Removed  - a duplicate of  (#112)
# Removed  - a duplicate of  (#113)
# Removed  - a duplicate of  (#114)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#115)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C-1(1)
# Removed  - a duplicate of  (#116)
# Removed  - a duplicate of  (#117)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#118)
# Removed  - a duplicate of  (#119)
# Removed  - a duplicate of  (#120)
# Removed  - a duplicate of  (#121)
# Removed  - a duplicate of  (#122)
# Removed  - a duplicate of  (#123)
# Removed  - a duplicate of  (#124)
# Removed  - a duplicate of  (#125)
# Removed  - a duplicate of  (#126)
# Removed  - a duplicate of  (#127)
# Removed  - a duplicate of  (#128)
# Removed  - a duplicate of  (#129)
# Removed  - a duplicate of  (#130)
# Removed  - a duplicate of  (#131)
# Removed  - a duplicate of  (#132)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# Removed  - a duplicate of  (#133)
# Removed  - a duplicate of  (#134)
# Removed  - a duplicate of  (#135)
# Removed  - a duplicate of  (#136)
# Removed  - a duplicate of  (#137)
# Removed  - a duplicate of  (#138)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# 39854 molecules converted
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# Removed  - a duplicate of  (#5)
# Removed  - a duplicate of  (#6)
# Removed  - a duplicate of  (#7)
# Removed  - a duplicate of  (#8)
# Removed  - a duplicate of  (#9)
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# Removed  - a duplicate of  (#12)
# Removed  - a duplicate of  (#13)
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# Removed  - a duplicate of  (#16)
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# Removed  - a duplicate of  (#35)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#36)
# Removed  - a duplicate of  (#37)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# Removed  - a duplicate of  (#43)
# Removed  - a duplicate of  (#44)
# Removed  - a duplicate of  (#45)
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#48)
# Removed  - a duplicate of  (#49)
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# Removed  - a duplicate of  (#54)
# Removed  - a duplicate of  (#55)
# Removed  - a duplicate of  (#56)
# Removed  - a duplicate of  (#57)
# Removed  - a duplicate of  (#58)
# Removed  - a duplicate of  (#59)
# Removed  - a duplicate of  (#60)
# Removed  - a duplicate of  (#61)
# Removed  - a duplicate of  (#62)
# Removed  - a duplicate of  (#63)
# Removed  - a duplicate of  (#64)
# Removed  - a duplicate of  (#65)
# Removed  - a duplicate of  (#66)
# Removed  - a duplicate of  (#67)
# Removed  - a duplicate of  (#68)
# Removed  - a duplicate of  (#69)
# Removed  - a duplicate of  (#70)
# Removed  - a duplicate of  (#71)
# Removed  - a duplicate of  (#72)
# Removed  - a duplicate of  (#73)
# Removed  - a duplicate of  (#74)
# Removed  - a duplicate of  (#75)
# Removed  - a duplicate of  (#76)
# Removed  - a duplicate of  (#77)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(1);
# Removed  - a duplicate of  (#78)
# Removed  - a duplicate of  (#79)
# Removed  - a duplicate of  (#80)
# Removed  - a duplicate of  (#81)
# Removed  - a duplicate of  (#82)
# Removed  - a duplicate of  (#83)
# Removed  - a duplicate of  (#84)
# Removed  - a duplicate of  (#85)
# Removed  - a duplicate of  (#86)
# Removed  - a duplicate of  (#87)
# Removed  - a duplicate of  (#88)
# Removed  - a duplicate of  (#89)
# Removed  - a duplicate of  (#90)
# Removed  - a duplicate of  (#91)
# Removed  - a duplicate of  (#92)
# Removed  - a duplicate of  (#93)
# Removed  - a duplicate of  (#94)
# Removed  - a duplicate of  (#95)
# Removed  - a duplicate of  (#96)
# Removed  - a duplicate of  (#97)
# Removed  - a duplicate of  (#98)
# Removed  - a duplicate of  (#99)
# Removed  - a duplicate of  (#100)
# Removed  - a duplicate of  (#101)
# Removed  - a duplicate of  (#102)
# Removed  - a duplicate of  (#103)
# Removed  - a duplicate of  (#104)
# Removed  - a duplicate of  (#105)
# Removed  - a duplicate of  (#106)
# Removed  - a duplicate of  (#107)
# Removed  - a duplicate of  (#108)
# Removed  - a duplicate of  (#109)
# Removed  - a duplicate of  (#110)
# Removed  - a duplicate of  (#111)
# Removed  - a duplicate of  (#112)
# Removed  - a duplicate of  (#113)
# Removed  - a duplicate of  (#114)
# Removed  - a duplicate of  (#115)
# Removed  - a duplicate of  (#116)
# Removed  - a duplicate of  (#117)
# Removed  - a duplicate of  (#118)
# Removed  - a duplicate of  (#119)
# Removed  - a duplicate of  (#120)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#121)
# Removed  - a duplicate of  (#122)
# Removed  - a duplicate of  (#123)
# Removed  - a duplicate of  (#124)
# Removed  - a duplicate of  (#125)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# Removed  - a duplicate of  (#126)
# Removed  - a duplicate of  (#127)
# Removed  - a duplicate of  (#128)
# Removed  - a duplicate of  (#129)
# Removed  - a duplicate of  (#130)
# Removed  - a duplicate of  (#131)
# Removed  - a duplicate of  (#132)
# Removed  - a duplicate of  (#133)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#134)
# Removed  - a duplicate of  (#135)
# Removed  - a duplicate of  (#136)
# Removed  - a duplicate of  (#137)
# Removed  - a duplicate of  (#138)
# Removed  - a duplicate of  (#139)
# Removed  - a duplicate of  (#140)
# Removed  - a duplicate of  (#141)
# Removed  - a duplicate of  (#142)
# Removed  - a duplicate of  (#143)
# Removed  - a duplicate of  (#144)
# Removed  - a duplicate of  (#145)
# Removed  - a duplicate of  (#146)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#147)
# Removed  - a duplicate of  (#148)
# Removed  - a duplicate of  (#149)
# Removed  - a duplicate of  (#150)
# Removed  - a duplicate of  (#151)
# Removed  - a duplicate of  (#152)
# Removed  - a duplicate of  (#153)
# Removed  - a duplicate of  (#154)
# Removed  - a duplicate of  (#155)
# Removed  - a duplicate of  (#156)
# Removed  - a duplicate of  (#157)
# Removed  - a duplicate of  (#158)
# Removed  - a duplicate of  (#159)
# Removed  - a duplicate of  (#160)
# Removed  - a duplicate of  (#161)
# Removed  - a duplicate of  (#162)
# Removed  - a duplicate of  (#163)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#164)
# Removed  - a duplicate of  (#165)
# Removed  - a duplicate of  (#166)
# Removed  - a duplicate of  (#167)
# Removed  - a duplicate of  (#168)
# Removed  - a duplicate of  (#169)
# Removed  - a duplicate of  (#170)
# Removed  - a duplicate of  (#171)
# Removed  - a duplicate of  (#172)
# Removed  - a duplicate of  (#173)
# Removed  - a duplicate of  (#174)
# Removed  - a duplicate of  (#175)
# Removed  - a duplicate of  (#176)
# Removed  - a duplicate of  (#177)
# Removed  - a duplicate of  (#178)
# Removed  - a duplicate of  (#179)
# Removed  - a duplicate of  (#180)
# Removed  - a duplicate of  (#181)
# Removed  - a duplicate of  (#182)
# Removed  - a duplicate of  (#183)
# Removed  - a duplicate of  (#184)
# Removed  - a duplicate of  (#185)
# Removed  - a duplicate of  (#186)
# Removed  - a duplicate of  (#187)
# Removed  - a duplicate of  (#188)
# Removed  - a duplicate of  (#189)
# Removed  - a duplicate of  (#190)
# Removed  - a duplicate of  (#191)
# Removed  - a duplicate of  (#192)
# Removed  - a duplicate of  (#193)
# Removed  - a duplicate of  (#194)
# Removed  - a duplicate of  (#195)
# Removed  - a duplicate of  (#196)
# Removed  - a duplicate of  (#197)
# Removed  - a duplicate of  (#198)
# Removed  - a duplicate of  (#199)
# Removed  - a duplicate of  (#200)
# Removed  - a duplicate of  (#201)
# Removed  - a duplicate of  (#202)
# Removed  - a duplicate of  (#203)
# Removed  - a duplicate of  (#204)
# Removed  - a duplicate of  (#205)
# Removed  - a duplicate of  (#206)
# Removed  - a duplicate of  (#207)
# Removed  - a duplicate of  (#208)
# Removed  - a duplicate of  (#209)
# Removed  - a duplicate of  (#210)
# Removed  - a duplicate of  (#211)
# Removed  - a duplicate of  (#212)
# Removed  - a duplicate of  (#213)
# Removed  - a duplicate of  (#214)
# Removed  - a duplicate of  (#215)
# Removed  - a duplicate of  (#216)
# Removed  - a duplicate of  (#217)
# Removed  - a duplicate of  (#218)
# Removed  - a duplicate of  (#219)
# Removed  - a duplicate of  (#220)
# Removed  - a duplicate of  (#221)
# Removed  - a duplicate of  (#222)
# Removed  - a duplicate of  (#223)
# Removed  - a duplicate of  (#224)
# Removed  - a duplicate of  (#225)
# Removed  - a duplicate of  (#226)
# Removed  - a duplicate of  (#227)
# Removed  - a duplicate of  (#228)
# Removed  - a duplicate of  (#229)
# Removed  - a duplicate of  (#230)
# Removed  - a duplicate of  (#231)
# Removed  - a duplicate of  (#232)
# Removed  - a duplicate of  (#233)
# Removed  - a duplicate of  (#234)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#235)
# Removed  - a duplicate of  (#236)
# Removed  - a duplicate of  (#237)
# Removed  - a duplicate of  (#238)
# Removed  - a duplicate of  (#239)
# Removed  - a duplicate of  (#240)
# Removed  - a duplicate of  (#241)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#242)
# Removed  - a duplicate of  (#243)
# Removed  - a duplicate of  (#244)
# Removed  - a duplicate of  (#245)
# Removed  - a duplicate of  (#246)
# Removed  - a duplicate of  (#247)
# Removed  - a duplicate of  (#248)
# Removed  - a duplicate of  (#249)
# Removed  - a duplicate of  (#250)
# Removed  - a duplicate of  (#251)
# Removed  - a duplicate of  (#252)
# Removed  - a duplicate of  (#253)
# Removed  - a duplicate of  (#254)
# Removed  - a duplicate of  (#255)
# Removed  - a duplicate of  (#256)
# Removed  - a duplicate of  (#257)
# Removed  - a duplicate of  (#258)
# Removed  - a duplicate of  (#259)
# Removed  - a duplicate of  (#260)
# Removed  - a duplicate of  (#261)
# Removed  - a duplicate of  (#262)
# Removed  - a duplicate of  (#263)
# Removed  - a duplicate of  (#264)
# Removed  - a duplicate of  (#265)
# Removed  - a duplicate of  (#266)
# Removed  - a duplicate of  (#267)
# Removed  - a duplicate of  (#268)
# Removed  - a duplicate of  (#269)
# Removed  - a duplicate of  (#270)
# Removed  - a duplicate of  (#271)
# Removed  - a duplicate of  (#272)
# Removed  - a duplicate of  (#273)
# Removed  - a duplicate of  (#274)
# Removed  - a duplicate of  (#275)
# Removed  - a duplicate of  (#276)
# Removed  - a duplicate of  (#277)
# Removed  - a duplicate of  (#278)
# Removed  - a duplicate of  (#279)
# Removed  - a duplicate of  (#280)
# Removed  - a duplicate of  (#281)
# Removed  - a duplicate of  (#282)
# Removed  - a duplicate of  (#283)
# Removed  - a duplicate of  (#284)
# Removed  - a duplicate of  (#285)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#286)
# Removed  - a duplicate of  (#287)
# Removed  - a duplicate of  (#288)
# Removed  - a duplicate of  (#289)
# Removed  - a duplicate of  (#290)
# Removed  - a duplicate of  (#291)
# Removed  - a duplicate of  (#292)
# Removed  - a duplicate of  (#293)
# Removed  - a duplicate of  (#294)
# Removed  - a duplicate of  (#295)
# Removed  - a duplicate of  (#296)
# Removed  - a duplicate of  (#297)
# Removed  - a duplicate of  (#298)
# Removed  - a duplicate of  (#299)
# Removed  - a duplicate of  (#300)
# Removed  - a duplicate of  (#301)
# Removed  - a duplicate of  (#302)
# Removed  - a duplicate of  (#303)
# Removed  - a duplicate of  (#304)
# Removed  - a duplicate of  (#305)
# Removed  - a duplicate of  (#306)
# Removed  - a duplicate of  (#307)
# Removed  - a duplicate of  (#308)
# Removed  - a duplicate of  (#309)
# Removed  - a duplicate of  (#310)
# Removed  - a duplicate of  (#311)
# Removed  - a duplicate of  (#312)
# Removed  - a duplicate of  (#313)
# Removed  - a duplicate of  (#314)
# Removed  - a duplicate of  (#315)
# Removed  - a duplicate of  (#316)
# Removed  - a duplicate of  (#317)
# Removed  - a duplicate of  (#318)
# Removed  - a duplicate of  (#319)
# Removed  - a duplicate of  (#320)
# Removed  - a duplicate of  (#321)
# Removed  - a duplicate of  (#322)
# Removed  - a duplicate of  (#323)
# Removed  - a duplicate of  (#324)
# Removed  - a duplicate of  (#325)
# Removed  - a duplicate of  (#326)
# Removed  - a duplicate of  (#327)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#328)
# Removed  - a duplicate of  (#329)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#330)
# Removed  - a duplicate of  (#331)
# Removed  - a duplicate of  (#332)
# Removed  - a duplicate of  (#333)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#334)
# Removed  - a duplicate of  (#335)
# Removed  - a duplicate of  (#336)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#337)
# Removed  - a duplicate of  (#338)
# Removed  - a duplicate of  (#339)
# Removed  - a duplicate of  (#340)
# Removed  - a duplicate of  (#341)
# Removed  - a duplicate of  (#342)
# Removed  - a duplicate of  (#343)
# Removed  - a duplicate of  (#344)
# Removed  - a duplicate of  (#345)
# Removed  - a duplicate of  (#346)
# Removed  - a duplicate of  (#347)
# Removed  - a duplicate of  (#348)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#349)
# Removed  - a duplicate of  (#350)
# Removed  - a duplicate of  (#351)
# Removed  - a duplicate of  (#352)
# Removed  - a duplicate of  (#353)
# Removed  - a duplicate of  (#354)
# Removed  - a duplicate of  (#355)
# Removed  - a duplicate of  (#356)
# Removed  - a duplicate of  (#357)
# Removed  - a duplicate of  (#358)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#359)
# Removed  - a duplicate of  (#360)
# Removed  - a duplicate of  (#361)
# Removed  - a duplicate of  (#362)
# Removed  - a duplicate of  (#363)
# Removed  - a duplicate of  (#364)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5)
# Removed  - a duplicate of  (#365)
# Removed  - a duplicate of  (#366)
# Removed  - a duplicate of  (#367)
# Removed  - a duplicate of  (#368)
# Removed  - a duplicate of  (#369)
# Removed  - a duplicate of  (#370)
# Removed  - a duplicate of  (#371)
# Removed  - a duplicate of  (#372)
# Removed  - a duplicate of  (#373)
# Removed  - a duplicate of  (#374)
# Removed  - a duplicate of  (#375)
# Removed  - a duplicate of  (#376)
# Removed  - a duplicate of  (#377)
# Removed  - a duplicate of  (#378)
# Removed  - a duplicate of  (#379)
# Removed  - a duplicate of  (#380)
# Removed  - a duplicate of  (#381)
# Removed  - a duplicate of  (#382)
# Removed  - a duplicate of  (#383)
# Removed  - a duplicate of  (#384)
# Removed  - a duplicate of  (#385)
# Removed  - a duplicate of  (#386)
# Removed  - a duplicate of  (#387)
# Removed  - a duplicate of  (#388)
# Removed  - a duplicate of  (#389)
# Removed  - a duplicate of  (#390)
# Removed  - a duplicate of  (#391)
# Removed  - a duplicate of  (#392)
# Removed  - a duplicate of  (#393)
# Removed  - a duplicate of  (#394)
# Removed  - a duplicate of  (#395)
# Removed  - a duplicate of  (#396)
# Removed  - a duplicate of  (#397)
# Removed  - a duplicate of  (#398)
# Removed  - a duplicate of  (#399)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#400)
# Removed  - a duplicate of  (#401)
# Removed  - a duplicate of  (#402)
# Removed  - a duplicate of  (#403)
# Removed  - a duplicate of  (#404)
# Removed  - a duplicate of  (#405)
# Removed  - a duplicate of  (#406)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#407)
# Removed  - a duplicate of  (#408)
# Removed  - a duplicate of  (#409)
# Removed  - a duplicate of  (#410)
# Removed  - a duplicate of  (#411)
# Removed  - a duplicate of  (#412)
# Removed  - a duplicate of  (#413)
# Removed  - a duplicate of  (#414)
# Removed  - a duplicate of  (#415)
# Removed  - a duplicate of  (#416)
# Removed  - a duplicate of  (#417)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#418)
# Removed  - a duplicate of  (#419)
# Removed  - a duplicate of  (#420)
# Removed  - a duplicate of  (#421)
# Removed  - a duplicate of  (#422)
# Removed  - a duplicate of  (#423)
# Removed  - a duplicate of  (#424)
# Removed  - a duplicate of  (#425)
# Removed  - a duplicate of  (#426)
# Removed  - a duplicate of  (#427)
# Removed  - a duplicate of  (#428)
# Removed  - a duplicate of  (#429)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#430)
# Removed  - a duplicate of  (#431)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1)
# Removed  - a duplicate of  (#432)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#433)
# Removed  - a duplicate of  (#434)
# Removed  - a duplicate of  (#435)
# Removed  - a duplicate of  (#436)
# Removed  - a duplicate of  (#437)
# Removed  - a duplicate of  (#438)
# Removed  - a duplicate of  (#439)
# Removed  - a duplicate of  (#440)
# Removed  - a duplicate of  (#441)
# Removed  - a duplicate of  (#442)
# Removed  - a duplicate of  (#443)
# Removed  - a duplicate of  (#444)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#445)
# Removed  - a duplicate of  (#446)
# Removed  - a duplicate of  (#447)
# Removed  - a duplicate of  (#448)
# Removed  - a duplicate of  (#449)
# Removed  - a duplicate of  (#450)
# Removed  - a duplicate of  (#451)
# Removed  - a duplicate of  (#452)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#453)
# Removed  - a duplicate of  (#454)
# Removed  - a duplicate of  (#455)
# Removed  - a duplicate of  (#456)
# Removed  - a duplicate of  (#457)
# Removed  - a duplicate of  (#458)
# Removed  - a duplicate of  (#459)
# Removed  - a duplicate of  (#460)
# Removed  - a duplicate of  (#461)
# Removed  - a duplicate of  (#462)
# Removed  - a duplicate of  (#463)
# Removed  - a duplicate of  (#464)
# Removed  - a duplicate of  (#465)
# Removed  - a duplicate of  (#466)
# Removed  - a duplicate of  (#467)
# Removed  - a duplicate of  (#468)
# Removed  - a duplicate of  (#469)
# Removed  - a duplicate of  (#470)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#471)
# Removed  - a duplicate of  (#472)
# Removed  - a duplicate of  (#473)
# Removed  - a duplicate of  (#474)
# Removed  - a duplicate of  (#475)
# Removed  - a duplicate of  (#476)
# Removed  - a duplicate of  (#477)
# Removed  - a duplicate of  (#478)
# Removed  - a duplicate of  (#479)
# Removed  - a duplicate of  (#480)
# Removed  - a duplicate of  (#481)
# Removed  - a duplicate of  (#482)
# Removed  - a duplicate of  (#483)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#484)
# Removed  - a duplicate of  (#485)
# Removed  - a duplicate of  (#486)
# Removed  - a duplicate of  (#487)
# Removed  - a duplicate of  (#488)
# Removed  - a duplicate of  (#489)
# Removed  - a duplicate of  (#490)
# Removed  - a duplicate of  (#491)
# Removed  - a duplicate of  (#492)
# Removed  - a duplicate of  (#493)
# Removed  - a duplicate of  (#494)
# Removed  - a duplicate of  (#495)
# Removed  - a duplicate of  (#496)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# Removed  - a duplicate of  (#497)
# Removed  - a duplicate of  (#498)
# Removed  - a duplicate of  (#499)
# Removed  - a duplicate of  (#500)
# Removed  - a duplicate of  (#501)
# Removed  - a duplicate of  (#502)
# Removed  - a duplicate of  (#503)
# Removed  - a duplicate of  (#504)
# Removed  - a duplicate of  (#505)
# Removed  - a duplicate of  (#506)
# Removed  - a duplicate of  (#507)
# Removed  - a duplicate of  (#508)
# Removed  - a duplicate of  (#509)
# Removed  - a duplicate of  (#510)
# Removed  - a duplicate of  (#511)
# Removed  - a duplicate of  (#512)
# Removed  - a duplicate of  (#513)
# Removed  - a duplicate of  (#514)
# Removed  - a duplicate of  (#515)
# Removed  - a duplicate of  (#516)
# Removed  - a duplicate of  (#517)
# Removed  - a duplicate of  (#518)
# Removed  - a duplicate of  (#519)
# Removed  - a duplicate of  (#520)
# Removed  - a duplicate of  (#521)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#522)
# Removed  - a duplicate of  (#523)
# Removed  - a duplicate of  (#524)
# Removed  - a duplicate of  (#525)
# Removed  - a duplicate of  (#526)
# Removed  - a duplicate of  (#527)
# Removed  - a duplicate of  (#528)
# Removed  - a duplicate of  (#529)
# Removed  - a duplicate of  (#530)
# Removed  - a duplicate of  (#531)
# Removed  - a duplicate of  (#532)
# Removed  - a duplicate of  (#533)
# Removed  - a duplicate of  (#534)
# Removed  - a duplicate of  (#535)
# Removed  - a duplicate of  (#536)
# Removed  - a duplicate of  (#537)
# Removed  - a duplicate of  (#538)
# Removed  - a duplicate of  (#539)
# Removed  - a duplicate of  (#540)
# Removed  - a duplicate of  (#541)
# Removed  - a duplicate of  (#542)
# Removed  - a duplicate of  (#543)
# Removed  - a duplicate of  (#544)
# Removed  - a duplicate of  (#545)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#546)
# Removed  - a duplicate of  (#547)
# Removed  - a duplicate of  (#548)
# Removed  - a duplicate of  (#549)
# Removed  - a duplicate of  (#550)
# Removed  - a duplicate of  (#551)
# Removed  - a duplicate of  (#552)
# Removed  - a duplicate of  (#553)
# Removed  - a duplicate of  (#554)
# Removed  - a duplicate of  (#555)
# Removed  - a duplicate of  (#556)
# Removed  - a duplicate of  (#557)
# Removed  - a duplicate of  (#558)
# Removed  - a duplicate of  (#559)
# Removed  - a duplicate of  (#560)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#561)
# Removed  - a duplicate of  (#562)
# Removed  - a duplicate of  (#563)
# Removed  - a duplicate of  (#564)
# Removed  - a duplicate of  (#565)
# Removed  - a duplicate of  (#566)
# Removed  - a duplicate of  (#567)
# Removed  - a duplicate of  (#568)
# Removed  - a duplicate of  (#569)
# Removed  - a duplicate of  (#570)
# Removed  - a duplicate of  (#571)
# Removed  - a duplicate of  (#572)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#573)
# Removed  - a duplicate of  (#574)
# Removed  - a duplicate of  (#575)
# Removed  - a duplicate of  (#576)
# Removed  - a duplicate of  (#577)
# Removed  - a duplicate of  (#578)
# Removed  - a duplicate of  (#579)
# Removed  - a duplicate of  (#580)
# Removed  - a duplicate of  (#581)
# Removed  - a duplicate of  (#582)
# Removed  - a duplicate of  (#583)
# Removed  - a duplicate of  (#584)
# Removed  - a duplicate of  (#585)
# Removed  - a duplicate of  (#586)
# Removed  - a duplicate of  (#587)
# Removed  - a duplicate of  (#588)
# Removed  - a duplicate of  (#589)
# Removed  - a duplicate of  (#590)
# Removed  - a duplicate of  (#591)
# Removed  - a duplicate of  (#592)
# Removed  - a duplicate of  (#593)
# Removed  - a duplicate of  (#594)
# Removed  - a duplicate of  (#595)
# Removed  - a duplicate of  (#596)
# Removed  - a duplicate of  (#597)
# Removed  - a duplicate of  (#598)
# Removed  - a duplicate of  (#599)
# Removed  - a duplicate of  (#600)
# Removed  - a duplicate of  (#601)
# Removed  - a duplicate of  (#602)
# Removed  - a duplicate of  (#603)
# Removed  - a duplicate of  (#604)
# Removed  - a duplicate of  (#605)
# Removed  - a duplicate of  (#606)
# Removed  - a duplicate of  (#607)
# Removed  - a duplicate of  (#608)
# Removed  - a duplicate of  (#609)
# Removed  - a duplicate of  (#610)
# Removed  - a duplicate of  (#611)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#612)
# Removed  - a duplicate of  (#613)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#614)
# Removed  - a duplicate of  (#615)
# Removed  - a duplicate of  (#616)
# Removed  - a duplicate of  (#617)
# Removed  - a duplicate of  (#618)
# Removed  - a duplicate of  (#619)
# Removed  - a duplicate of  (#620)
# Removed  - a duplicate of  (#621)
# Removed  - a duplicate of  (#622)
# Removed  - a duplicate of  (#623)
# Removed  - a duplicate of  (#624)
# Removed  - a duplicate of  (#625)
# Removed  - a duplicate of  (#626)
# Removed  - a duplicate of  (#627)
# Removed  - a duplicate of  (#628)
# Removed  - a duplicate of  (#629)
# Removed  - a duplicate of  (#630)
# Removed  - a duplicate of  (#631)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#632)
# Removed  - a duplicate of  (#633)
# Removed  - a duplicate of  (#634)
# Removed  - a duplicate of  (#635)
# Removed  - a duplicate of  (#636)
# Removed  - a duplicate of  (#637)
# Removed  - a duplicate of  (#638)
# Removed  - a duplicate of  (#639)
# Removed  - a duplicate of  (#640)
# Removed  - a duplicate of  (#641)
# Removed  - a duplicate of  (#642)
# Removed  - a duplicate of  (#643)
# Removed  - a duplicate of  (#644)
# Removed  - a duplicate of  (#645)
# Removed  - a duplicate of  (#646)
# Removed  - a duplicate of  (#647)
# Removed  - a duplicate of  (#648)
# Removed  - a duplicate of  (#649)
# Removed  - a duplicate of  (#650)
# Removed  - a duplicate of  (#651)
# Removed  - a duplicate of  (#652)
# Removed  - a duplicate of  (#653)
# Removed  - a duplicate of  (#654)
# Removed  - a duplicate of  (#655)
# Removed  - a duplicate of  (#656)
# Removed  - a duplicate of  (#657)
# Removed  - a duplicate of  (#658)
# Removed  - a duplicate of  (#659)
# Removed  - a duplicate of  (#660)
# Removed  - a duplicate of  (#661)
# Removed  - a duplicate of  (#662)
# Removed  - a duplicate of  (#663)
# Removed  - a duplicate of  (#664)
# Removed  - a duplicate of  (#665)
# Removed  - a duplicate of  (#666)
# Removed  - a duplicate of  (#667)
# Removed  - a duplicate of  (#668)
# Removed  - a duplicate of  (#669)
# Removed  - a duplicate of  (#670)
# Removed  - a duplicate of  (#671)
# Removed  - a duplicate of  (#672)
# Removed  - a duplicate of  (#673)
# Removed  - a duplicate of  (#674)
# Removed  - a duplicate of  (#675)
# Removed  - a duplicate of  (#676)
# Removed  - a duplicate of  (#677)
# Removed  - a duplicate of  (#678)
# Removed  - a duplicate of  (#679)
# Removed  - a duplicate of  (#680)
# Removed  - a duplicate of  (#681)
# Removed  - a duplicate of  (#682)
# Removed  - a duplicate of  (#683)
# Removed  - a duplicate of  (#684)
# Removed  - a duplicate of  (#685)
# Removed  - a duplicate of  (#686)
# Removed  - a duplicate of  (#687)
# Removed  - a duplicate of  (#688)
# Removed  - a duplicate of  (#689)
# Removed  - a duplicate of  (#690)
# Removed  - a duplicate of  (#691)
# Removed  - a duplicate of  (#692)
# Removed  - a duplicate of  (#693)
# Removed  - a duplicate of  (#694)
# Removed  - a duplicate of  (#695)
# Removed  - a duplicate of  (#696)
# Removed  - a duplicate of  (#697)
# Removed  - a duplicate of  (#698)
# Removed  - a duplicate of  (#699)
# Removed  - a duplicate of  (#700)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#701)
# Removed  - a duplicate of  (#702)
# Removed  - a duplicate of  (#703)
# Removed  - a duplicate of  (#704)
# Removed  - a duplicate of  (#705)
# Removed  - a duplicate of  (#706)
# Removed  - a duplicate of  (#707)
# Removed  - a duplicate of  (#708)
# Removed  - a duplicate of  (#709)
# Removed  - a duplicate of  (#710)
# Removed  - a duplicate of  (#711)
# Removed  - a duplicate of  (#712)
# Removed  - a duplicate of  (#713)
# Removed  - a duplicate of  (#714)
# Removed  - a duplicate of  (#715)
# Removed  - a duplicate of  (#716)
# Removed  - a duplicate of  (#717)
# Removed  - a duplicate of  (#718)
# Removed  - a duplicate of  (#719)
# Removed  - a duplicate of  (#720)
# Removed  - a duplicate of  (#721)
# Removed  - a duplicate of  (#722)
# Removed  - a duplicate of  (#723)
# Removed  - a duplicate of  (#724)
# Removed  - a duplicate of  (#725)
# Removed  - a duplicate of  (#726)
# Removed  - a duplicate of  (#727)
# Removed  - a duplicate of  (#728)
# Removed  - a duplicate of  (#729)
# Removed  - a duplicate of  (#730)
# Removed  - a duplicate of  (#731)
# Removed  - a duplicate of  (#732)
# Removed  - a duplicate of  (#733)
# Removed  - a duplicate of  (#734)
# Removed  - a duplicate of  (#735)
# Removed  - a duplicate of  (#736)
# Removed  - a duplicate of  (#737)
# Removed  - a duplicate of  (#738)
# Removed  - a duplicate of  (#739)
# Removed  - a duplicate of  (#740)
# Removed  - a duplicate of  (#741)
# Removed  - a duplicate of  (#742)
# Removed  - a duplicate of  (#743)
# Removed  - a duplicate of  (#744)
# Removed  - a duplicate of  (#745)
# Removed  - a duplicate of  (#746)
# Removed  - a duplicate of  (#747)
# Removed  - a duplicate of  (#748)
# Removed  - a duplicate of  (#749)
# Removed  - a duplicate of  (#750)
# Removed  - a duplicate of  (#751)
# Removed  - a duplicate of  (#752)
# Removed  - a duplicate of  (#753)
# Removed  - a duplicate of  (#754)
# Removed  - a duplicate of  (#755)
# Removed  - a duplicate of  (#756)
# Removed  - a duplicate of  (#757)
# Removed  - a duplicate of  (#758)
# Removed  - a duplicate of  (#759)
# Removed  - a duplicate of  (#760)
# Removed  - a duplicate of  (#761)
# Removed  - a duplicate of  (#762)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N-1(1);
# Removed  - a duplicate of  (#763)
# Removed  - a duplicate of  (#764)
# Removed  - a duplicate of  (#765)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#766)
# Removed  - a duplicate of  (#767)
# Removed  - a duplicate of  (#768)
# Removed  - a duplicate of  (#769)
# Removed  - a duplicate of  (#770)
# Removed  - a duplicate of  (#771)
# Removed  - a duplicate of  (#772)
# Removed  - a duplicate of  (#773)
# 114211 molecules converted
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# Removed  - a duplicate of  (#5)
# Removed  - a duplicate of  (#6)
# Removed  - a duplicate of  (#7)
# Removed  - a duplicate of  (#8)
# Removed  - a duplicate of  (#9)
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# Removed  - a duplicate of  (#12)
# Removed  - a duplicate of  (#13)
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# Removed  - a duplicate of  (#16)
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# Removed  - a duplicate of  (#35)
# Removed  - a duplicate of  (#36)
# Removed  - a duplicate of  (#37)
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# Removed  - a duplicate of  (#43)
# Removed  - a duplicate of  (#44)
# Removed  - a duplicate of  (#45)
# Removed  - a duplicate of  (#46)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(2);
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# Removed  - a duplicate of  (#49)
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# Removed  - a duplicate of  (#54)
# Removed  - a duplicate of  (#55)
# Removed  - a duplicate of  (#56)
# Removed  - a duplicate of  (#57)
# Removed  - a duplicate of  (#58)
# Removed  - a duplicate of  (#59)
# Removed  - a duplicate of  (#60)
# Removed  - a duplicate of  (#61)
# Removed  - a duplicate of  (#62)
# Removed  - a duplicate of  (#63)
# Removed  - a duplicate of  (#64)
# Removed  - a duplicate of  (#65)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#66)
# Removed  - a duplicate of  (#67)
# Removed  - a duplicate of  (#68)
# Removed  - a duplicate of  (#69)
# Removed  - a duplicate of  (#70)
# Removed  - a duplicate of  (#71)
# Removed  - a duplicate of  (#72)
# Removed  - a duplicate of  (#73)
# Removed  - a duplicate of  (#74)
# Removed  - a duplicate of  (#75)
# Removed  - a duplicate of  (#76)
# Removed  - a duplicate of  (#77)
# Removed  - a duplicate of  (#78)
# Removed  - a duplicate of  (#79)
# Removed  - a duplicate of  (#80)
# Removed  - a duplicate of  (#81)
# Removed  - a duplicate of  (#82)
# Removed  - a duplicate of  (#83)
# Removed  - a duplicate of  (#84)
# Removed  - a duplicate of  (#85)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#86)
# Removed  - a duplicate of  (#87)
# Removed  - a duplicate of  (#88)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#89)
# Removed  - a duplicate of  (#90)
# Removed  - a duplicate of  (#91)
# Removed  - a duplicate of  (#92)
# Removed  - a duplicate of  (#93)
# Removed  - a duplicate of  (#94)
# Removed  - a duplicate of  (#95)
# Removed  - a duplicate of  (#96)
# Removed  - a duplicate of  (#97)
# Removed  - a duplicate of  (#98)
# Removed  - a duplicate of  (#99)
# Removed  - a duplicate of  (#100)
# Removed  - a duplicate of  (#101)
# Removed  - a duplicate of  (#102)
# Removed  - a duplicate of  (#103)
# Removed  - a duplicate of  (#104)
# Removed  - a duplicate of  (#105)
# Removed  - a duplicate of  (#106)
# Removed  - a duplicate of  (#107)
# Removed  - a duplicate of  (#108)
# Removed  - a duplicate of  (#109)
# Removed  - a duplicate of  (#110)
# Removed  - a duplicate of  (#111)
# Removed  - a duplicate of  (#112)
# Removed  - a duplicate of  (#113)
# Removed  - a duplicate of  (#114)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#115)
# Removed  - a duplicate of  (#116)
# Removed  - a duplicate of  (#117)
# Removed  - a duplicate of  (#118)
# Removed  - a duplicate of  (#119)
# Removed  - a duplicate of  (#120)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#121)
# Removed  - a duplicate of  (#122)
# Removed  - a duplicate of  (#123)
# Removed  - a duplicate of  (#124)
# Removed  - a duplicate of  (#125)
# Removed  - a duplicate of  (#126)
# Removed  - a duplicate of  (#127)
# Removed  - a duplicate of  (#128)
# Removed  - a duplicate of  (#129)
# Removed  - a duplicate of  (#130)
# Removed  - a duplicate of  (#131)
# Removed  - a duplicate of  (#132)
# Removed  - a duplicate of  (#133)
# Removed  - a duplicate of  (#134)
# Removed  - a duplicate of  (#135)
# Removed  - a duplicate of  (#136)
# Removed  - a duplicate of  (#137)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#138)
# Removed  - a duplicate of  (#139)
# Removed  - a duplicate of  (#140)
# Removed  - a duplicate of  (#141)
# Removed  - a duplicate of  (#142)
# Removed  - a duplicate of  (#143)
# Removed  - a duplicate of  (#144)
# Removed  - a duplicate of  (#145)
# Removed  - a duplicate of  (#146)
# Removed  - a duplicate of  (#147)
# Removed  - a duplicate of  (#148)
# Removed  - a duplicate of  (#149)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#150)
# Removed  - a duplicate of  (#151)
# Removed  - a duplicate of  (#152)
# Removed  - a duplicate of  (#153)
# Removed  - a duplicate of  (#154)
# Removed  - a duplicate of  (#155)
# Removed  - a duplicate of  (#156)
# Removed  - a duplicate of  (#157)
# Removed  - a duplicate of  (#158)
# Removed  - a duplicate of  (#159)
# Removed  - a duplicate of  (#160)
# Removed  - a duplicate of  (#161)
# Removed  - a duplicate of  (#162)
# Removed  - a duplicate of  (#163)
# Removed  - a duplicate of  (#164)
# Removed  - a duplicate of  (#165)
# Removed  - a duplicate of  (#166)
# Removed  - a duplicate of  (#167)
# Removed  - a duplicate of  (#168)
# Removed  - a duplicate of  (#169)
# Removed  - a duplicate of  (#170)
# Removed  - a duplicate of  (#171)
# Removed  - a duplicate of  (#172)
# Removed  - a duplicate of  (#173)
# Removed  - a duplicate of  (#174)
# Removed  - a duplicate of  (#175)
# Removed  - a duplicate of  (#176)
# Removed  - a duplicate of  (#177)
# Removed  - a duplicate of  (#178)
# Removed  - a duplicate of  (#179)
# Removed  - a duplicate of  (#180)
# Removed  - a duplicate of  (#181)
# Removed  - a duplicate of  (#182)
# Removed  - a duplicate of  (#183)
# Removed  - a duplicate of  (#184)
# Removed  - a duplicate of  (#185)
# Removed  - a duplicate of  (#186)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#187)
# Removed  - a duplicate of  (#188)
# Removed  - a duplicate of  (#189)
# Removed  - a duplicate of  (#190)
# Removed  - a duplicate of  (#191)
# Removed  - a duplicate of  (#192)
# Removed  - a duplicate of  (#193)
# Removed  - a duplicate of  (#194)
# Removed  - a duplicate of  (#195)
# Removed  - a duplicate of  (#196)
# Removed  - a duplicate of  (#197)
# Removed  - a duplicate of  (#198)
# Removed  - a duplicate of  (#199)
# Removed  - a duplicate of  (#200)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#201)
# Removed  - a duplicate of  (#202)
# Removed  - a duplicate of  (#203)
# Removed  - a duplicate of  (#204)
# Removed  - a duplicate of  (#205)
# Removed  - a duplicate of  (#206)
# Removed  - a duplicate of  (#207)
# Removed  - a duplicate of  (#208)
# Removed  - a duplicate of  (#209)
# Removed  - a duplicate of  (#210)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#211)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#212)
# Removed  - a duplicate of  (#213)
# Removed  - a duplicate of  (#214)
# Removed  - a duplicate of  (#215)
# Removed  - a duplicate of  (#216)
# Removed  - a duplicate of  (#217)
# Removed  - a duplicate of  (#218)
# Removed  - a duplicate of  (#219)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#220)
# Removed  - a duplicate of  (#221)
# Removed  - a duplicate of  (#222)
# Removed  - a duplicate of  (#223)
# Removed  - a duplicate of  (#224)
# ...
# Removed  - a duplicate of  (#3395)
# Removed  - a duplicate of  (#3396)
# Removed  - a duplicate of  (#3397)
# Removed  - a duplicate of  (#3398)
# Removed  - a duplicate of  (#3399)
# Removed  - a duplicate of  (#3400)
# Removed  - a duplicate of  (#3401)
# Removed  - a duplicate of  (#3402)
# Removed  - a duplicate of  (#3403)
# Removed  - a duplicate of  (#3404)
# Removed  - a duplicate of  (#3405)
# Removed  - a duplicate of  (#3406)
# Removed  - a duplicate of  (#3407)
# Removed  - a duplicate of  (#3408)
# Removed  - a duplicate of  (#3409)
# Removed  - a duplicate of  (#3410)
# Removed  - a duplicate of  (#3411)
# Removed  - a duplicate of  (#3412)
# Removed  - a duplicate of  (#3413)
# Removed  - a duplicate of  (#3414)
# Removed  - a duplicate of  (#3415)
# Removed  - a duplicate of  (#3416)
# Removed  - a duplicate of  (#3417)
# Removed  - a duplicate of  (#3418)
# Removed  - a duplicate of  (#3419)
# Removed  - a duplicate of  (#3420)
# Removed  - a duplicate of  (#3421)
# Removed  - a duplicate of  (#3422)
# Removed  - a duplicate of  (#3423)
# Removed  - a duplicate of  (#3424)
# Removed  - a duplicate of  (#3425)
# Removed  - a duplicate of  (#3426)
# Removed  - a duplicate of  (#3427)
# Removed  - a duplicate of  (#3428)
# Removed  - a duplicate of  (#3429)
# Removed  - a duplicate of  (#3430)
# Removed  - a duplicate of  (#3431)
# Removed  - a duplicate of  (#3432)
# Removed  - a duplicate of  (#3433)
# Removed  - a duplicate of  (#3434)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2);
# Removed  - a duplicate of  (#3435)
# Removed  - a duplicate of  (#3436)
# Removed  - a duplicate of  (#3437)
# Removed  - a duplicate of  (#3438)
# Removed  - a duplicate of  (#3439)
# Removed  - a duplicate of  (#3440)
# Removed  - a duplicate of  (#3441)
# Removed  - a duplicate of  (#3442)
# Removed  - a duplicate of  (#3443)
# Removed  - a duplicate of  (#3444)
# Removed  - a duplicate of  (#3445)
# Removed  - a duplicate of  (#3446)
# Removed  - a duplicate of  (#3447)
# Removed  - a duplicate of  (#3448)
# Removed  - a duplicate of  (#3449)
# Removed  - a duplicate of  (#3450)
# Removed  - a duplicate of  (#3451)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#3452)
# Removed  - a duplicate of  (#3453)
# Removed  - a duplicate of  (#3454)
# Removed  - a duplicate of  (#3455)
# Removed  - a duplicate of  (#3456)
# Removed  - a duplicate of  (#3457)
# Removed  - a duplicate of  (#3458)
# Removed  - a duplicate of  (#3459)
# Removed  - a duplicate of  (#3460)
# Removed  - a duplicate of  (#3461)
# Removed  - a duplicate of  (#3462)
# Removed  - a duplicate of  (#3463)
# Removed  - a duplicate of  (#3464)
# Removed  - a duplicate of  (#3465)
# Removed  - a duplicate of  (#3466)
# Removed  - a duplicate of  (#3467)
# Removed  - a duplicate of  (#3468)
# Removed  - a duplicate of  (#3469)
# Removed  - a duplicate of  (#3470)
# Removed  - a duplicate of  (#3471)
# Removed  - a duplicate of  (#3472)
# Removed  - a duplicate of  (#3473)
# Removed  - a duplicate of  (#3474)
# Removed  - a duplicate of  (#3475)
# Removed  - a duplicate of  (#3476)
# Removed  - a duplicate of  (#3477)
# Removed  - a duplicate of  (#3478)
# Removed  - a duplicate of  (#3479)
# Removed  - a duplicate of  (#3480)
# Removed  - a duplicate of  (#3481)
# Removed  - a duplicate of  (#3482)
# Removed  - a duplicate of  (#3483)
# Removed  - a duplicate of  (#3484)
# Removed  - a duplicate of  (#3485)
# Removed  - a duplicate of  (#3486)
# Removed  - a duplicate of  (#3487)
# Removed  - a duplicate of  (#3488)
# Removed  - a duplicate of  (#3489)
# Removed  - a duplicate of  (#3490)
# Removed  - a duplicate of  (#3491)
# Removed  - a duplicate of  (#3492)
# Removed  - a duplicate of  (#3493)
# Removed  - a duplicate of  (#3494)
# Removed  - a duplicate of  (#3495)
# Removed  - a duplicate of  (#3496)
# Removed  - a duplicate of  (#3497)
# Removed  - a duplicate of  (#3498)
# Removed  - a duplicate of  (#3499)
# Removed  - a duplicate of  (#3500)
# Removed  - a duplicate of  (#3501)
# Removed  - a duplicate of  (#3502)
# Removed  - a duplicate of  (#3503)
# Removed  - a duplicate of  (#3504)
# Removed  - a duplicate of  (#3505)
# Removed  - a duplicate of  (#3506)
# Removed  - a duplicate of  (#3507)
# Removed  - a duplicate of  (#3508)
# Removed  - a duplicate of  (#3509)
# Removed  - a duplicate of  (#3510)
# Removed  - a duplicate of  (#3511)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#3512)
# Removed  - a duplicate of  (#3513)
# Removed  - a duplicate of  (#3514)
# Removed  - a duplicate of  (#3515)
# Removed  - a duplicate of  (#3516)
# Removed  - a duplicate of  (#3517)
# Removed  - a duplicate of  (#3518)
# Removed  - a duplicate of  (#3519)
# Removed  - a duplicate of  (#3520)
# Removed  - a duplicate of  (#3521)
# Removed  - a duplicate of  (#3522)
# Removed  - a duplicate of  (#3523)
# Removed  - a duplicate of  (#3524)
# Removed  - a duplicate of  (#3525)
# Removed  - a duplicate of  (#3526)
# Removed  - a duplicate of  (#3527)
# Removed  - a duplicate of  (#3528)
# Removed  - a duplicate of  (#3529)
# Removed  - a duplicate of  (#3530)
# Removed  - a duplicate of  (#3531)
# Removed  - a duplicate of  (#3532)
# Removed  - a duplicate of  (#3533)
# Removed  - a duplicate of  (#3534)
# Removed  - a duplicate of  (#3535)
# Removed  - a duplicate of  (#3536)
# Removed  - a duplicate of  (#3537)
# Removed  - a duplicate of  (#3538)
# Removed  - a duplicate of  (#3539)
# Removed  - a duplicate of  (#3540)
# Removed  - a duplicate of  (#3541)
# Removed  - a duplicate of  (#3542)
# Removed  - a duplicate of  (#3543)
# Removed  - a duplicate of  (#3544)
# Removed  - a duplicate of  (#3545)
# Removed  - a duplicate of  (#3546)
# Removed  - a duplicate of  (#3547)
# Removed  - a duplicate of  (#3548)
# Removed  - a duplicate of  (#3549)
# Removed  - a duplicate of  (#3550)
# Removed  - a duplicate of  (#3551)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#3552)
# Removed  - a duplicate of  (#3553)
# Removed  - a duplicate of  (#3554)
# Removed  - a duplicate of  (#3555)
# Removed  - a duplicate of  (#3556)
# Removed  - a duplicate of  (#3557)
# Removed  - a duplicate of  (#3558)
# Removed  - a duplicate of  (#3559)
# Removed  - a duplicate of  (#3560)
# Removed  - a duplicate of  (#3561)
# Removed  - a duplicate of  (#3562)
# Removed  - a duplicate of  (#3563)
# Removed  - a duplicate of  (#3564)
# Removed  - a duplicate of  (#3565)
# Removed  - a duplicate of  (#3566)
# Removed  - a duplicate of  (#3567)
# Removed  - a duplicate of  (#3568)
# Removed  - a duplicate of  (#3569)
# Removed  - a duplicate of  (#3570)
# Removed  - a duplicate of  (#3571)
# Removed  - a duplicate of  (#3572)
# Removed  - a duplicate of  (#3573)
# Removed  - a duplicate of  (#3574)
# Removed  - a duplicate of  (#3575)
# Removed  - a duplicate of  (#3576)
# Removed  - a duplicate of  (#3577)
# Removed  - a duplicate of  (#3578)
# Removed  - a duplicate of  (#3579)
# Removed  - a duplicate of  (#3580)
# Removed  - a duplicate of  (#3581)
# Removed  - a duplicate of  (#3582)
# Removed  - a duplicate of  (#3583)
# Removed  - a duplicate of  (#3584)
# Removed  - a duplicate of  (#3585)
# Removed  - a duplicate of  (#3586)
# Removed  - a duplicate of  (#3587)
# Removed  - a duplicate of  (#3588)
# Removed  - a duplicate of  (#3589)
# Removed  - a duplicate of  (#3590)
# Removed  - a duplicate of  (#3591)
# Removed  - a duplicate of  (#3592)
# Removed  - a duplicate of  (#3593)
# Removed  - a duplicate of  (#3594)
# Removed  - a duplicate of  (#3595)
# Removed  - a duplicate of  (#3596)
# Removed  - a duplicate of  (#3597)
# Removed  - a duplicate of  (#3598)
# Removed  - a duplicate of  (#3599)
# Removed  - a duplicate of  (#3600)
# Removed  - a duplicate of  (#3601)
# Removed  - a duplicate of  (#3602)
# Removed  - a duplicate of  (#3603)
# Removed  - a duplicate of  (#3604)
# Removed  - a duplicate of  (#3605)
# Removed  - a duplicate of  (#3606)
# Removed  - a duplicate of  (#3607)
# Removed  - a duplicate of  (#3608)
# Removed  - a duplicate of  (#3609)
# Removed  - a duplicate of  (#3610)
# Removed  - a duplicate of  (#3611)
# Removed  - a duplicate of  (#3612)
# Removed  - a duplicate of  (#3613)
# Removed  - a duplicate of  (#3614)
# Removed  - a duplicate of  (#3615)
# Removed  - a duplicate of  (#3616)
# Removed  - a duplicate of  (#3617)
# Removed  - a duplicate of  (#3618)
# Removed  - a duplicate of  (#3619)
# Removed  - a duplicate of  (#3620)
# Removed  - a duplicate of  (#3621)
# Removed  - a duplicate of  (#3622)
# Removed  - a duplicate of  (#3623)
# Removed  - a duplicate of  (#3624)
# Removed  - a duplicate of  (#3625)
# Removed  - a duplicate of  (#3626)
# Removed  - a duplicate of  (#3627)
# Removed  - a duplicate of  (#3628)
# Removed  - a duplicate of  (#3629)
# Removed  - a duplicate of  (#3630)
# Removed  - a duplicate of  (#3631)
# Removed  - a duplicate of  (#3632)
# Removed  - a duplicate of  (#3633)
# Removed  - a duplicate of  (#3634)
# Removed  - a duplicate of  (#3635)
# Removed  - a duplicate of  (#3636)
# Removed  - a duplicate of  (#3637)
# Removed  - a duplicate of  (#3638)
# Removed  - a duplicate of  (#3639)
# Removed  - a duplicate of  (#3640)
# Removed  - a duplicate of  (#3641)
# Removed  - a duplicate of  (#3642)
# Removed  - a duplicate of  (#3643)
# Removed  - a duplicate of  (#3644)
# Removed  - a duplicate of  (#3645)
# Removed  - a duplicate of  (#3646)
# Removed  - a duplicate of  (#3647)
# Removed  - a duplicate of  (#3648)
# Removed  - a duplicate of  (#3649)
# Removed  - a duplicate of  (#3650)
# Removed  - a duplicate of  (#3651)
# Removed  - a duplicate of  (#3652)
# Removed  - a duplicate of  (#3653)
# Removed  - a duplicate of  (#3654)
# Removed  - a duplicate of  (#3655)
# Removed  - a duplicate of  (#3656)
# Removed  - a duplicate of  (#3657)
# Removed  - a duplicate of  (#3658)
# Removed  - a duplicate of  (#3659)
# Removed  - a duplicate of  (#3660)
# Removed  - a duplicate of  (#3661)
# Removed  - a duplicate of  (#3662)
# Removed  - a duplicate of  (#3663)
# Removed  - a duplicate of  (#3664)
# Removed  - a duplicate of  (#3665)
# Removed  - a duplicate of  (#3666)
# Removed  - a duplicate of  (#3667)
# Removed  - a duplicate of  (#3668)
# Removed  - a duplicate of  (#3669)
# Removed  - a duplicate of  (#3670)
# Removed  - a duplicate of  (#3671)
# Removed  - a duplicate of  (#3672)
# Removed  - a duplicate of  (#3673)
# Removed  - a duplicate of  (#3674)
# Removed  - a duplicate of  (#3675)
# Removed  - a duplicate of  (#3676)
# Removed  - a duplicate of  (#3677)
# Removed  - a duplicate of  (#3678)
# Removed  - a duplicate of  (#3679)
# Removed  - a duplicate of  (#3680)
# Removed  - a duplicate of  (#3681)
# Removed  - a duplicate of  (#3682)
# Removed  - a duplicate of  (#3683)
# Removed  - a duplicate of  (#3684)
# Removed  - a duplicate of  (#3685)
# Removed  - a duplicate of  (#3686)
# Removed  - a duplicate of  (#3687)
# Removed  - a duplicate of  (#3688)
# Removed  - a duplicate of  (#3689)
# Removed  - a duplicate of  (#3690)
# Removed  - a duplicate of  (#3691)
# Removed  - a duplicate of  (#3692)
# Removed  - a duplicate of  (#3693)
# Removed  - a duplicate of  (#3694)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N-1(1)
# Removed  - a duplicate of  (#3695)
# Removed  - a duplicate of  (#3696)
# Removed  - a duplicate of  (#3697)
# Removed  - a duplicate of  (#3698)
# Removed  - a duplicate of  (#3699)
# Removed  - a duplicate of  (#3700)
# Removed  - a duplicate of  (#3701)
# Removed  - a duplicate of  (#3702)
# Removed  - a duplicate of  (#3703)
# Removed  - a duplicate of  (#3704)
# Removed  - a duplicate of  (#3705)
# Removed  - a duplicate of  (#3706)
# Removed  - a duplicate of  (#3707)
# Removed  - a duplicate of  (#3708)
# Removed  - a duplicate of  (#3709)
# Removed  - a duplicate of  (#3710)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#3711)
# Removed  - a duplicate of  (#3712)
# Removed  - a duplicate of  (#3713)
# Removed  - a duplicate of  (#3714)
# Removed  - a duplicate of  (#3715)
# Removed  - a duplicate of  (#3716)
# Removed  - a duplicate of  (#3717)
# Removed  - a duplicate of  (#3718)
# Removed  - a duplicate of  (#3719)
# Removed  - a duplicate of  (#3720)
# Removed  - a duplicate of  (#3721)
# Removed  - a duplicate of  (#3722)
# Removed  - a duplicate of  (#3723)
# Removed  - a duplicate of  (#3724)
# Removed  - a duplicate of  (#3725)
# Removed  - a duplicate of  (#3726)
# Removed  - a duplicate of  (#3727)
# Removed  - a duplicate of  (#3728)
# Removed  - a duplicate of  (#3729)
# Removed  - a duplicate of  (#3730)
# Removed  - a duplicate of  (#3731)
# Removed  - a duplicate of  (#3732)
# Removed  - a duplicate of  (#3733)
# Removed  - a duplicate of  (#3734)
# Removed  - a duplicate of  (#3735)
# Removed  - a duplicate of  (#3736)
# Removed  - a duplicate of  (#3737)
# Removed  - a duplicate of  (#3738)
# Removed  - a duplicate of  (#3739)
# Removed  - a duplicate of  (#3740)
# Removed  - a duplicate of  (#3741)
# Removed  - a duplicate of  (#3742)
# Removed  - a duplicate of  (#3743)
# Removed  - a duplicate of  (#3744)
# Removed  - a duplicate of  (#3745)
# Removed  - a duplicate of  (#3746)
# Removed  - a duplicate of  (#3747)
# Removed  - a duplicate of  (#3748)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#3749)
# Removed  - a duplicate of  (#3750)
# Removed  - a duplicate of  (#3751)
# Removed  - a duplicate of  (#3752)
# Removed  - a duplicate of  (#3753)
# Removed  - a duplicate of  (#3754)
# Removed  - a duplicate of  (#3755)
# Removed  - a duplicate of  (#3756)
# Removed  - a duplicate of  (#3757)
# Removed  - a duplicate of  (#3758)
# Removed  - a duplicate of  (#3759)
# Removed  - a duplicate of  (#3760)
# Removed  - a duplicate of  (#3761)
# Removed  - a duplicate of  (#3762)
# Removed  - a duplicate of  (#3763)
# Removed  - a duplicate of  (#3764)
# Removed  - a duplicate of  (#3765)
# Removed  - a duplicate of  (#3766)
# Removed  - a duplicate of  (#3767)
# Removed  - a duplicate of  (#3768)
# Removed  - a duplicate of  (#3769)
# Removed  - a duplicate of  (#3770)
# Removed  - a duplicate of  (#3771)
# Removed  - a duplicate of  (#3772)
# Removed  - a duplicate of  (#3773)
# Removed  - a duplicate of  (#3774)
# Removed  - a duplicate of  (#3775)
# Removed  - a duplicate of  (#3776)
# Removed  - a duplicate of  (#3777)
# Removed  - a duplicate of  (#3778)
# Removed  - a duplicate of  (#3779)
# Removed  - a duplicate of  (#3780)
# Removed  - a duplicate of  (#3781)
# Removed  - a duplicate of  (#3782)
# Removed  - a duplicate of  (#3783)
# Removed  - a duplicate of  (#3784)
# Removed  - a duplicate of  (#3785)
# Removed  - a duplicate of  (#3786)
# Removed  - a duplicate of  (#3787)
# Removed  - a duplicate of  (#3788)
# Removed  - a duplicate of  (#3789)
# Removed  - a duplicate of  (#3790)
# Removed  - a duplicate of  (#3791)
# Removed  - a duplicate of  (#3792)
# Removed  - a duplicate of  (#3793)
# Removed  - a duplicate of  (#3794)
# Removed  - a duplicate of  (#3795)
# Removed  - a duplicate of  (#3796)
# Removed  - a duplicate of  (#3797)
# Removed  - a duplicate of  (#3798)
# Removed  - a duplicate of  (#3799)
# Removed  - a duplicate of  (#3800)
# Removed  - a duplicate of  (#3801)
# Removed  - a duplicate of  (#3802)
# Removed  - a duplicate of  (#3803)
# Removed  - a duplicate of  (#3804)
# Removed  - a duplicate of  (#3805)
# Removed  - a duplicate of  (#3806)
# Removed  - a duplicate of  (#3807)
# Removed  - a duplicate of  (#3808)
# Removed  - a duplicate of  (#3809)
# Removed  - a duplicate of  (#3810)
# Removed  - a duplicate of  (#3811)
# Removed  - a duplicate of  (#3812)
# Removed  - a duplicate of  (#3813)
# Removed  - a duplicate of  (#3814)
# Removed  - a duplicate of  (#3815)
# Removed  - a duplicate of  (#3816)
# Removed  - a duplicate of  (#3817)
# Removed  - a duplicate of  (#3818)
# Removed  - a duplicate of  (#3819)
# Removed  - a duplicate of  (#3820)
# Removed  - a duplicate of  (#3821)
# Removed  - a duplicate of  (#3822)
# Removed  - a duplicate of  (#3823)
# Removed  - a duplicate of  (#3824)
# Removed  - a duplicate of  (#3825)
# 286142 molecules converted

# %%
filelist['ref'] = Path("/home/nobilm@usi.ch/auc_generation/ds_val_no_dups/Maybridge_HitDiscover_valid_unique.smiles")
# filelist['train'] = Path("/home/nobilm@usi.ch/auc_generation/ds_val_no_dups/guacamol_v1_valid_unique.smiles")
filelist['ref_train_intersection'] = Path("/home/nobilm@usi.ch/auc_generation/data/train_dataset/guacamol/Maybridge_HitDiscover_intersection_guacamol_v1_train.smiles")

# %%
for k, v in filelist.items():
    print(k, v, count_rows(v))
# Out:
# file_1 /home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_10k_valids_unique.smiles 9966
# file_2 /home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_60k_valids_unique.smiles 59329
# file_3 /home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_110k_valids_unique.smiles 109244
# file_4 /home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_160k_valids_unique.smiles 115063
# file_5 /home/nobilm@usi.ch/auc_generation/future_data/molgpt_guacamol_qed_210k_valids_unique.smiles 207322
# ref /home/nobilm@usi.ch/auc_generation/ds_val_no_dups/Maybridge_HitDiscover_valid_unique.smiles 50734
# train /home/nobilm@usi.ch/auc_generation/ds_val_no_dups/guacamol_v1_valid_unique.smiles 1272168
# ref_train_intersection /home/nobilm@usi.ch/auc_generation/data/train_dataset/guacamol/Maybridge_HitDiscover_intersection_guacamol_v1_train.smiles 8306

# %%
generations = {
    'file_1': 0,
    'file_2': 0,
    'file_3': 0,
    'file_4': 0,
    'file_5': 0,
}

# %%
def count_intersection(a, b):
    merged = merge_files(a, b, out_path/"merged.smiles")
    len_merged = count_rows(merged)
    merged_unique = get_valid_non_duplicates(merged)
    len_merged_unique = count_rows(merged_unique)
    delete_file(merged)
    delete_file(merged_unique)
    return len_merged-len_merged_unique

def get_value_for_file(filekey):
    count_in_ref = count_intersection(filelist['ref'], filelist[filekey])
    count_in_ref_train_intersection = count_intersection(filelist['ref_train_intersection'], filelist[filekey])
    return count_in_ref - count_in_ref_train_intersection

# %%
# %%capture
# multiprocess this
for f in generations.keys():
    generations[f] = get_value_for_file(f)
# Out:
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Salt was disconnected;
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# 60698 molecules converted
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#5)
# 18267 molecules converted
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Salt was disconnected;
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2);
# Removed  - a duplicate of  (#2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# Removed  - a duplicate of  (#4)
# Removed  - a duplicate of  (#5)
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C-1(2)
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5)
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#10)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#11)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#12)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#14)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# 110049 molecules converted
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C-1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5)
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# 67626 molecules converted
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Salt was disconnected;
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(1);
# Removed  - a duplicate of  (#5)
# Removed  - a duplicate of  (#6)
# Removed  - a duplicate of  (#7)
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#9)
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#12)
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# Removed  - a duplicate of  (#16)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#19)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#23)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# Removed  - a duplicate of  (#32)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#35)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#36)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#37)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#43)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#44)
# Removed  - a duplicate of  (#45)
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#49)
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# Removed  - a duplicate of  (#54)
# Removed  - a duplicate of  (#55)
# Removed  - a duplicate of  (#56)
# Removed  - a duplicate of  (#57)
# Removed  - a duplicate of  (#58)
# Removed  - a duplicate of  (#59)
# Removed  - a duplicate of  (#60)
# Removed  - a duplicate of  (#61)
# Removed  - a duplicate of  (#62)
# Removed  - a duplicate of  (#63)
# Removed  - a duplicate of  (#64)
# Removed  - a duplicate of  (#65)
# Removed  - a duplicate of  (#66)
# Removed  - a duplicate of  (#67)
# Removed  - a duplicate of  (#68)
# Removed  - a duplicate of  (#69)
# Removed  - a duplicate of  (#70)
# Removed  - a duplicate of  (#71)
# Removed  - a duplicate of  (#72)
# Removed  - a duplicate of  (#73)
# Removed  - a duplicate of  (#74)
# Removed  - a duplicate of  (#75)
# Removed  - a duplicate of  (#76)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#77)
# Removed  - a duplicate of  (#78)
# Removed  - a duplicate of  (#79)
# Removed  - a duplicate of  (#80)
# Removed  - a duplicate of  (#81)
# Removed  - a duplicate of  (#82)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#83)
# Removed  - a duplicate of  (#84)
# Removed  - a duplicate of  (#85)
# Removed  - a duplicate of  (#86)
# Removed  - a duplicate of  (#87)
# Removed  - a duplicate of  (#88)
# Removed  - a duplicate of  (#89)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#90)
# Removed  - a duplicate of  (#91)
# Removed  - a duplicate of  (#92)
# Removed  - a duplicate of  (#93)
# Removed  - a duplicate of  (#94)
# Removed  - a duplicate of  (#95)
# Removed  - a duplicate of  (#96)
# Removed  - a duplicate of  (#97)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#98)
# Removed  - a duplicate of  (#99)
# Removed  - a duplicate of  (#100)
# Removed  - a duplicate of  (#101)
# Removed  - a duplicate of  (#102)
# Removed  - a duplicate of  (#103)
# 159875 molecules converted
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(1);
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# Removed  - a duplicate of  (#12)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5)
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# Removed  - a duplicate of  (#14)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#15)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#16)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#35)
# Removed  - a duplicate of  (#36)
# Removed  - a duplicate of  (#37)
# Removed  - a duplicate of  (#38)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#39)
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#43)
# Removed  - a duplicate of  (#44)
# Removed  - a duplicate of  (#45)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# Removed  - a duplicate of  (#49)
# 117501 molecules converted
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Salt was disconnected;
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#12)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si-1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#16)
# Removed  - a duplicate of  (#17)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#20)
# Removed  - a duplicate of  (#21)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2)
# Removed  - a duplicate of  (#29)
# Removed  - a duplicate of  (#30)
# Removed  - a duplicate of  (#31)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#32)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#33)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# Removed  - a duplicate of  (#34)
# Removed  - a duplicate of  (#35)
# Removed  - a duplicate of  (#36)
# Removed  - a duplicate of  (#37)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# Removed  - a duplicate of  (#40)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P+1(5)
# Removed  - a duplicate of  (#41)
# Removed  - a duplicate of  (#42)
# Removed  - a duplicate of  (#43)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#44)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#45)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#49)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# Removed  - a duplicate of  (#54)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#55)
# Removed  - a duplicate of  (#56)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N-1(1);
# Removed  - a duplicate of  (#57)
# Removed  - a duplicate of  (#58)
# Removed  - a duplicate of  (#59)
# Removed  - a duplicate of  (#60)
# Removed  - a duplicate of  (#61)
# Removed  - a duplicate of  (#62)
# Removed  - a duplicate of  (#63)
# Removed  - a duplicate of  (#64)
# Removed  - a duplicate of  (#65)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#66)
# Removed  - a duplicate of  (#67)
# Removed  - a duplicate of  (#68)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#69)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#70)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#71)
# Removed  - a duplicate of  (#72)
# Removed  - a duplicate of  (#73)
# Removed  - a duplicate of  (#74)
# Removed  - a duplicate of  (#75)
# Removed  - a duplicate of  (#76)
# Removed  - a duplicate of  (#77)
# Removed  - a duplicate of  (#78)
# Removed  - a duplicate of  (#79)
# Removed  - a duplicate of  (#80)
# Removed  - a duplicate of  (#81)
# Removed  - a duplicate of  (#82)
# Removed  - a duplicate of  (#83)
# Removed  - a duplicate of  (#84)
# Removed  - a duplicate of  (#85)
# Removed  - a duplicate of  (#86)
# Removed  - a duplicate of  (#87)
# 165710 molecules converted
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#6)
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si-1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Se(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#10)
# Removed  - a duplicate of  (#11)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#12)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# Removed  - a duplicate of  (#14)
# Removed  - a duplicate of  (#15)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#16)
# Removed  - a duplicate of  (#17)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P+1(5)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#20)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#21)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#22)
# Removed  - a duplicate of  (#23)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N-1(1);
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# Removed  - a duplicate of  (#28)
# Removed  - a duplicate of  (#29)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#30)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#31)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# Removed  - a duplicate of  (#34)
# Removed  - a duplicate of  (#35)
# Removed  - a duplicate of  (#36)
# 123333 molecules converted
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Salt was disconnected;
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized;
# Removed  - a duplicate of  (#1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#10)
# ==============================
# ...
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#103)
# Removed  - a duplicate of  (#104)
# Removed  - a duplicate of  (#105)
# Removed  - a duplicate of  (#106)
# Removed  - a duplicate of  (#107)
# Removed  - a duplicate of  (#108)
# Removed  - a duplicate of  (#109)
# Removed  - a duplicate of  (#110)
# Removed  - a duplicate of  (#111)
# Removed  - a duplicate of  (#112)
# Removed  - a duplicate of  (#113)
# Removed  - a duplicate of  (#114)
# Removed  - a duplicate of  (#115)
# Removed  - a duplicate of  (#116)
# Removed  - a duplicate of  (#117)
# Removed  - a duplicate of  (#118)
# 257937 molecules converted
# Removed  - a duplicate of  (#1)
# Removed  - a duplicate of  (#2)
# Removed  - a duplicate of  (#3)
# Removed  - a duplicate of  (#4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized;
# Removed  - a duplicate of  (#5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# Removed  - a duplicate of  (#7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#8)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#9)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P+1(5)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized;
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): B-1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Charges neutralized
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(5);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): C-1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#10)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#11)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# Removed  - a duplicate of  (#12)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7);
# Removed  - a duplicate of  (#13)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#14)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#15)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P+1(5)
# Removed  - a duplicate of  (#16)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#17)
# Removed  - a duplicate of  (#18)
# Removed  - a duplicate of  (#19)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#20)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#21)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#22)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# Removed  - a duplicate of  (#23)
# Removed  - a duplicate of  (#24)
# Removed  - a duplicate of  (#25)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#26)
# Removed  - a duplicate of  (#27)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#28)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#29)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#30)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N+1(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#31)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#32)
# Removed  - a duplicate of  (#33)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): N(2);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# Removed  - a duplicate of  (#34)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): Si(3);
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): P(7)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#35)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1);
# Removed  - a duplicate of  (#36)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(6)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#37)
# Removed  - a duplicate of  (#38)
# Removed  - a duplicate of  (#39)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4);
# Removed  - a duplicate of  (#40)
# Removed  - a duplicate of  (#41)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): S+1(4)
# Removed  - a duplicate of  (#42)
# Removed  - a duplicate of  (#43)
# Removed  - a duplicate of  (#44)
# ==============================
# *** Open Babel Warning  in InChI code
#   #1 :Accepted unusual valence(s): O(1)
# Removed  - a duplicate of  (#45)
# Removed  - a duplicate of  (#46)
# Removed  - a duplicate of  (#47)
# Removed  - a duplicate of  (#48)
# Removed  - a duplicate of  (#49)
# Removed  - a duplicate of  (#50)
# Removed  - a duplicate of  (#51)
# Removed  - a duplicate of  (#52)
# Removed  - a duplicate of  (#53)
# 215574 molecules converted

# %%
generations
# Out:
# {'file_1': -3, 'file_2': 5, 'file_3': 54, 'file_4': 51, 'file_5': 65}

# %%
import matplotlib.pyplot as plt
plt.plot(list(generations.keys()),list(generations.values()))

# %%
plt.savefig('foo.png')

# %%
#Fill under the curve
plt.fill_between(
        x = list(generations.keys()), 
        y1 = list(generations.values()), 
        # where= (-1 < t)&(t < 1), 
        color= "b",
        alpha= 0.2)

# %%
# import numpy as np
# from sklearn.metrics import auc

# dx = 5
# xx = np.arange(1,100,dx)
# yy = np.arange(1,100,dx)

# print('computed AUC using sklearn.metrics.auc: {}'.format(auc(xx,yy)))

# %%
# import numpy as np
# from scipy.integrate import simpson
# from numpy import trapz

# y = list(generations.values())
# x = [i for i in range(len(list(generations.values())))]


# # Compute the area using the composite trapezoidal rule.
# area = trapz(y, dx=5)
# print("area =", area)

# # Compute the area using the composite Simpson's rule.
# area = simpson(y, dx=5)
# print("area =", area)
